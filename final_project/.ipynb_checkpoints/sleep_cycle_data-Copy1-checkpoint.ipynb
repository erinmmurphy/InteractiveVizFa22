# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sleep = pd.read_csv('sleep_cycle_data_1.csv')

df_sleep.head(10)
# Out:
#          Date              Start                End Sleep Quality  \
# 0    6/3/2015    6/3/15 11:49 PM     6/4/15 7:48 AM           94%
# 1    6/5/2015    6/5/15 12:04 AM    6/5/15 10:01 AM          100%
# 2    6/7/2015    6/7/15 12:17 AM     6/7/15 7:33 AM           87%
# 3    6/8/2015    6/8/15 12:20 AM     6/8/15 8:17 AM           83%
# 4    6/9/2015    6/9/15 12:30 AM     6/9/15 7:46 AM           70%
# 5   10/2/2015   10/2/15 12:02 AM    10/2/15 7:26 AM           79%
# 6  12/23/2015  12/23/15 10:49 PM   12/24/15 4:46 AM           67%
# 7  12/31/2015   12/31/15 8:22 AM  12/31/15 11:28 AM           40%
# 8   1/24/2016    1/24/16 2:06 AM   1/24/16 10:23 AM           67%
# 9   6/22/2016   6/22/16 12:18 AM    6/22/16 8:00 AM           72%
#
#    Sleep Quality.1 Regularity Mood  Heart rate (bpm)  Steps Alarm mode  ...  \
# 0             0.94         0%   OK                62   4251     Normal  ...
# 1             1.00         0%   OK                64   5660     Normal  ...
# ...

# %%
df_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1060 non-null   object
#  1   Start                        1060 non-null   object
#  2   End                          1060 non-null   object
#  3   Sleep Quality                1060 non-null   object
#  4   Sleep Quality.1              1060 non-null   float64
#  5   Regularity                   1060 non-null   object
#  6   Mood                         1051 non-null   object
#  7   Heart rate (bpm)             1060 non-null   int64
#  8   Steps                        1060 non-null   int64
#  9   Alarm mode                   1060 non-null   object
#  10  Air Pressure (Pa)            1060 non-null   float64
#  11  City                         1022 non-null   object
#  12  Movements per hour           1060 non-null   float64
# ...

# %%
df_sleep['Sleep Quality'] = df_sleep['Sleep Quality'].str.rstrip('%').astype('float') / 100.0

# %%
df_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1060 non-null   object
#  1   Start                        1060 non-null   object
#  2   End                          1060 non-null   object
#  3   Sleep Quality                1060 non-null   float64
#  4   Sleep Quality.1              1060 non-null   float64
#  5   Regularity                   1060 non-null   object
#  6   Mood                         1051 non-null   object
#  7   Heart rate (bpm)             1060 non-null   int64
#  8   Steps                        1060 non-null   int64
#  9   Alarm mode                   1060 non-null   object
#  10  Air Pressure (Pa)            1060 non-null   float64
#  11  City                         1022 non-null   object
#  12  Movements per hour           1060 non-null   float64
# ...

# %%
df_sleep.head(3)
# Out:
#        Date            Start              End  Sleep Quality  Sleep Quality.1  \
# 0  6/3/2015  6/3/15 11:49 PM   6/4/15 7:48 AM           0.94             0.94
# 1  6/5/2015  6/5/15 12:04 AM  6/5/15 10:01 AM           1.00             1.00
# 2  6/7/2015  6/7/15 12:17 AM   6/7/15 7:33 AM           0.87             0.87
#
#   Regularity Mood  Heart rate (bpm)  Steps Alarm mode  ...  \
# 0         0%   OK                62   4251     Normal  ...
# 1         0%   OK                64   5660     Normal  ...
# 2        78%   OK                60   7872     Normal  ...
#
#    Time in bed (seconds) Time asleep (seconds)  Time before sleep (seconds)  \
# 0                28788.2               25237.6                        191.9
# 1                35821.9               32000.9                        238.8
# 2                26199.8               23317.8                        611.3
#
#    Window start   Window stop  Did snore Snore time Weather temperature (°F)  \
# ...

# %%
df_sleep.describe()
# Out:
#        Sleep Quality  Heart rate (bpm)         Steps  Air Pressure (Pa)  \
# count    1060.000000       1060.000000   1060.000000        1060.000000
# mean        0.820415          1.048113   5521.809434         100.559623
# std         0.126888          8.260773   2612.777068           9.435436
# min         0.090000          0.000000      0.000000           0.000000
# 25%         0.760000          0.000000   3868.250000         101.000000
# 50%         0.840000          0.000000   5433.500000         101.500000
# 75%         0.910000          0.000000   7021.250000         102.100000
# max         1.000000         84.000000  23249.000000         103.800000
#
#        Movements per hour  Time in bed (seconds)  Time asleep (seconds)  \
# count         1060.000000            1060.000000            1060.000000
# mean            29.597264           28953.706038           26476.651226
# std             18.058431            5159.376136            5119.201553
# ...

# %%
df_sleep.describe().to_csv("sleep_describe.csv", index=True)

# %%
df_sleep['Regularity'] = df_sleep['Regularity'].str.rstrip('%').astype('float') / 100.0

# %%
df_sleep.head(4)
# Out:
#        Date            Start              End  Sleep Quality  Sleep Quality.1  \
# 0  6/3/2015  6/3/15 11:49 PM   6/4/15 7:48 AM           0.94             0.94
# 1  6/5/2015  6/5/15 12:04 AM  6/5/15 10:01 AM           1.00             1.00
# 2  6/7/2015  6/7/15 12:17 AM   6/7/15 7:33 AM           0.87             0.87
# 3  6/8/2015  6/8/15 12:20 AM   6/8/15 8:17 AM           0.83             0.83
#
#    Regularity Mood  Heart rate (bpm)  Steps Alarm mode  ...  \
# 0        0.00   OK                62   4251     Normal  ...
# 1        0.00   OK                64   5660     Normal  ...
# 2        0.78   OK                60   7872     Normal  ...
# 3        0.86   OK                61  23249     Normal  ...
#
#    Time in bed (seconds) Time asleep (seconds)  Time before sleep (seconds)  \
# 0                28788.2               25237.6                        191.9
# 1                35821.9               32000.9                        238.8
# ...

# %%
df_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Start                        1060 non-null   object
#  1   End                          1060 non-null   object
#  2   Sleep Quality                1060 non-null   float64
#  3   Regularity                   1060 non-null   float64
#  4   Mood                         1051 non-null   object
#  5   Heart rate (bpm)             1060 non-null   int64
#  6   Steps                        1060 non-null   int64
#  7   Alarm mode                   1060 non-null   object
#  8   Air Pressure (Pa)            1060 non-null   float64
#  9   City                         1022 non-null   object
#  10  Movements per hour           1060 non-null   float64
#  11  Time in bed (seconds)        1060 non-null   timedelta64[ns]
# ...

# %%
df_sleep['time_in_bed']= pd.to_datetime(df_sleep['Time in bed (seconds)'], unit='h')

# %%
df_sleep.head(4)
# Out:
#        Date            Start              End  Sleep Quality  Sleep Quality.1  \
# 0  6/3/2015  6/3/15 11:49 PM   6/4/15 7:48 AM           0.94             0.94
# 1  6/5/2015  6/5/15 12:04 AM  6/5/15 10:01 AM           1.00             1.00
# 2  6/7/2015  6/7/15 12:17 AM   6/7/15 7:33 AM           0.87             0.87
# 3  6/8/2015  6/8/15 12:20 AM   6/8/15 8:17 AM           0.83             0.83
#
#    Regularity Mood  Heart rate (bpm)  Steps Alarm mode  ...  \
# 0        0.00   OK                62   4251     Normal  ...
# 1        0.00   OK                64   5660     Normal  ...
# 2        0.78   OK                60   7872     Normal  ...
# 3        0.86   OK                61  23249     Normal  ...
#
#    Time asleep (seconds) Time before sleep (seconds)  Window start  \
# 0                25237.6                       191.9   6/4/15 7:20
# 1                32000.9                       238.8   6/5/15 9:30
# 2                23317.8                       611.3   6/7/15 7:00
# ...

# %%
df_sleep['Time in bed (seconds)']
# Out:
# 0       28788.2
# 1       35821.9
# 2       26199.8
# 3       28670.9
# 4       26182.5
#          ...
# 1055    21819.9
# 1056    25224.9
# 1057    14461.2
# 1058    26611.5
# 1059    24105.7
# Name: Time in bed (seconds), Length: 1060, dtype: float64

# %%
df_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1060 non-null   object
#  1   Start                        1060 non-null   object
#  2   End                          1060 non-null   object
#  3   Sleep Quality                1060 non-null   float64
#  4   Sleep Quality.1              1060 non-null   float64
#  5   Regularity                   1060 non-null   float64
#  6   Mood                         1051 non-null   object
#  7   Heart rate (bpm)             1060 non-null   int64
#  8   Steps                        1060 non-null   int64
#  9   Alarm mode                   1060 non-null   object
#  10  Air Pressure (Pa)            1060 non-null   float64
#  11  City                         1022 non-null   object
#  12  Movements per hour           1060 non-null   float64
# ...

# %%
df_sleep['time_in_bed']= df_sleep['Time in bed (seconds)'] /3600.00

# %%
df_sleep.head(4)
# Out:
#        Date            Start              End  Sleep Quality  Sleep Quality.1  \
# 0  6/3/2015  6/3/15 11:49 PM   6/4/15 7:48 AM           0.94             0.94
# 1  6/5/2015  6/5/15 12:04 AM  6/5/15 10:01 AM           1.00             1.00
# 2  6/7/2015  6/7/15 12:17 AM   6/7/15 7:33 AM           0.87             0.87
# 3  6/8/2015  6/8/15 12:20 AM   6/8/15 8:17 AM           0.83             0.83
#
#    Regularity Mood  Heart rate (bpm)  Steps Alarm mode  ...  \
# 0        0.00   OK                62   4251     Normal  ...
# 1        0.00   OK                64   5660     Normal  ...
# 2        0.78   OK                60   7872     Normal  ...
# 3        0.86   OK                61  23249     Normal  ...
#
#    Time asleep (seconds) Time before sleep (seconds)  Window start  \
# 0                25237.6                       191.9   6/4/15 7:20
# 1                32000.9                       238.8   6/5/15 9:30
# 2                23317.8                       611.3   6/7/15 7:00
# ...

# %%
df_sleep['time_before_sleep']= df_sleep['Time before sleep (seconds)'] /60

# %%
df_sleep.head(4)
# Out:
#        Date            Start              End  Sleep Quality  Sleep Quality.1  \
# 0  6/3/2015  6/3/15 11:49 PM   6/4/15 7:48 AM           0.94             0.94
# 1  6/5/2015  6/5/15 12:04 AM  6/5/15 10:01 AM           1.00             1.00
# 2  6/7/2015  6/7/15 12:17 AM   6/7/15 7:33 AM           0.87             0.87
# 3  6/8/2015  6/8/15 12:20 AM   6/8/15 8:17 AM           0.83             0.83
#
#    Regularity Mood  Heart rate (bpm)  Steps Alarm mode  ...  \
# 0        0.00   OK                62   4251     Normal  ...
# 1        0.00   OK                64   5660     Normal  ...
# 2        0.78   OK                60   7872     Normal  ...
# 3        0.86   OK                61  23249     Normal  ...
#
#    Time before sleep (seconds) Window start   Window stop  Did snore  \
# 0                        191.9  6/4/15 7:20   6/4/15 7:50      False
# 1                        238.8  6/5/15 9:30  6/5/15 10:00      False
# ...

# %%
df_sleep['time_asleep']= df_sleep['Time asleep (seconds)'] /3600.00

# %%
df_sleep.head(4)
# Out:
#        Date            Start              End  Sleep Quality  Sleep Quality.1  \
# 0  6/3/2015  6/3/15 11:49 PM   6/4/15 7:48 AM           0.94             0.94
# 1  6/5/2015  6/5/15 12:04 AM  6/5/15 10:01 AM           1.00             1.00
# 2  6/7/2015  6/7/15 12:17 AM   6/7/15 7:33 AM           0.87             0.87
# 3  6/8/2015  6/8/15 12:20 AM   6/8/15 8:17 AM           0.83             0.83
#
#    Regularity Mood  Heart rate (bpm)  Steps Alarm mode  ...  Window start  \
# 0        0.00   OK                62   4251     Normal  ...   6/4/15 7:20
# 1        0.00   OK                64   5660     Normal  ...   6/5/15 9:30
# 2        0.78   OK                60   7872     Normal  ...   6/7/15 7:00
# 3        0.86   OK                61  23249     Normal  ...   6/8/15 7:45
#
#     Window stop  Did snore  Snore time  Weather temperature (°F)  \
# 0   6/4/15 7:50      False           0                       32.0
# 1  6/5/15 10:00      False           0                       32.0
# ...

# %%
df_sleep['bedtime'] = pd.to_datetime(df_sleep['Start'])

# %%
df_sleep['bedtime']
# Out:
# 0      2015-06-03 23:49:00
# 1      2015-06-05 00:04:00
# 2      2015-06-07 00:17:00
# 3      2015-06-08 00:20:00
# 4      2015-06-09 00:30:00
#                ...
# 1055   2020-03-11 00:53:00
# 1056   2020-03-12 00:34:00
# 1057   2020-03-13 03:44:00
# 1058   2020-03-17 00:14:00
# 1059   2020-05-28 01:13:00
# Name: bedtime, Length: 1060, dtype: datetime64[ns]

# %%
df_sleep['wake_time'] = pd.to_datetime(df_sleep['End'])
df_sleep['wake_time']
# Out:
# 0      2015-06-04 07:48:00
# 1      2015-06-05 10:01:00
# 2      2015-06-07 07:33:00
# 3      2015-06-08 08:17:00
# 4      2015-06-09 07:46:00
#                ...
# 1055   2020-03-11 06:57:00
# 1056   2020-03-12 07:35:00
# 1057   2020-03-13 07:45:00
# 1058   2020-03-17 07:38:00
# 1059   2020-05-28 07:55:00
# Name: wake_time, Length: 1060, dtype: datetime64[ns]

# %%
df_sleep.to_csv("sleep_data_clean.csv", index=True)
